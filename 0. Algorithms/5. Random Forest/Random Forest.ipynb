# %% [markdown]
# #**Random Forest Theory**
#
# https://youtu.be/v6VJ2RO66Ag

# %% [markdown]
# #**Machine Learning Tutorial - Basic sklearn Random Forest model**
#
# https://youtu.be/s7vsF2bzQX8
#
# https://www.kaggle.com/code/funxexcel/p1-basic-sklearn-randon-forest-model/notebook

# %%
#STEP-1: Import Libraries
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
#STEP-2: Autheticate E-Mail ID
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
#STEP-3: Get File from Drive using file-ID
downloaded = drive.CreateFile({'id':'1fto9f5b6TwIZGW14_0wF1pPQ3CdbqfgG'}) # replace the id with id of file you want to access
downloaded.GetContentFile("heart_cleveland_upload.csv")

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv("heart_cleveland_upload.csv")
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     69    1   0       160   234    1        2      131      0      0.1
# 1     69    0   0       140   239    0        0      151      0      1.8
# 2     66    0   0       150   226    0        0      114      0      2.6
# 3     65    1   0       138   282    1        2      174      0      1.4
# 4     64    1   0       110   211    0        2      144      1      1.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 292   40    1   3       152   223    0        0      181      0      0.0
# 293   39    1   3       118   219    0        0      140      0      1.2
# 294   35    1   3       120   198    0        0      130      1      1.6
# 295   35    0   3       138   183    0        0      182      0      1.4
# 296   35    1   3       126   282    0        2      156      1      0.0
#
#      slope  ca  thal  condition
# 0        1   1     0          0
# ...

# %%
data.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalach      0
# exang        0
# oldpeak      0
# slope        0
# ca           0
# thal         0
# condition    0
# dtype: int64

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean    54.542088    0.676768    2.158249  131.693603  247.350168    0.144781
# std      9.049736    0.468500    0.964859   17.762806   51.997583    0.352474
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    2.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    2.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    3.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.996633  149.599327    0.326599    1.055556    0.602694    0.676768
# ...

# %%
y = data['condition']

#Load X Variables into a Pandas Dataframe with columns 
X = data.drop(['condition'], axis = 1)

# %%
X.shape
# Out:
# (297, 13)

# %%
y.shape
# Out:
# (297,)

# %% [markdown]
# **Divide Data into Train and test**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)


print(f'X_train : {X_train.shape}')
print(f'y_train : {y_train.shape}')
print(f'X_test : {X_test.shape}')
print(f'y_test : {y_test.shape}')
# Out:
# X_train : (237, 13)
# y_train : (237,)
# X_test : (60, 13)
# y_test : (60,)

# %% [markdown]
# **Build Basic Random Forest Model**

# %%
rf_Model = RandomForestClassifier(oob_score=True)
rf_Model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(oob_score=True)
